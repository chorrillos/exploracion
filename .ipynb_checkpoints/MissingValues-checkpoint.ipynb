# %% [markdown]
# Carga de datos

# %%
import pandas as pd

cloud="https://github.com/chorrillos/clustering/raw/main/variables.seleccionadas_21FEB.xlsx"
thedata=pd.read_excel(cloud)

# %%
thedata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1874 entries, 0 to 1873
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   UBIGEO          1874 non-null   int64
#  1   DEPARTAMENTO    1874 non-null   object
#  2   PROVINCIA       1874 non-null   object
#  3   Distrito        1874 non-null   object
#  4   Zona            1874 non-null   object
#  5   Latitud         1874 non-null   float64
#  6   Longitud        1874 non-null   float64
#  7   cobertura.cell  1852 non-null   float64
#  8   Educ.sec.comp   1874 non-null   float64
#  9   esp.vid.nacer   1874 non-null   float64
#  10  Ing.fam.p.cap   1874 non-null   float64
#  11  NBS.2017        1874 non-null   float64
#  12  No.Pobreza      1874 non-null   float64
#  13  Tasa.docen_pub  1873 non-null   float64
# dtypes: float64(9), int64(1), object(4)
# memory usage: 205.1+ KB

# %%
thedata.isnull().sum()
# Out:
# UBIGEO             0
# DEPARTAMENTO       0
# PROVINCIA          0
# Distrito           0
# Zona               0
# Latitud            0
# Longitud           0
# cobertura.cell    22
# Educ.sec.comp      0
# esp.vid.nacer      0
# Ing.fam.p.cap      0
# NBS.2017           0
# No.Pobreza         0
# Tasa.docen_pub     1
# dtype: int64

# %%
theVars=thedata.columns[7:] # variables a usar
thedata_sub=thedata.loc[:,theVars] # subset
thedata_sub
# Out:
#       cobertura.cell  Educ.sec.comp  esp.vid.nacer  Ing.fam.p.cap  NBS.2017  \
# 0          87.500000      79.562705      72.192674    1259.130244      88.0
# 1          11.111111      71.006832      71.364553     561.102634      26.6
# 2          32.142857      32.772384      68.594405     415.021047      62.2
# 3           6.250000      52.210906      77.528252     398.663339      72.7
# 4          30.232558      36.868932      72.460151     325.930531      40.9
# ...              ...            ...            ...            ...       ...
# 1869       18.840580      40.104714      80.048647     503.528398      40.8
# 1870       10.000000      40.397763      79.565489     459.209784      42.9
# 1871       20.689655      45.883427      82.510539     697.907476      39.3
# 1872       78.571429      43.119697      83.853720     662.652379      45.0
# 1873        1.818182      20.543648      67.273622     551.691331      29.3
#
#       No.Pobreza  Tasa.docen_pub
# 0      90.965375      200.541634
# 1      63.480051      138.888889
# 2      54.267038      188.564477
# 3      60.830218      287.648054
# 4      46.954338      101.892285
# ...          ...             ...
# 1869   87.100440      206.832872
# 1870   90.985455      251.228227
# 1871   88.053143      265.245708
# 1872   87.100440      136.268344
# 1873   68.071662      354.305347
#
# [1874 rows x 7 columns]

# %% [markdown]
# Imputación usando el algoritmo [MICE](https://www.scirp.org/journal/paperinformation.aspx?paperid=112455)

# %%
import miceforest as mf

# Crear kernel. 
kernel = mf.ImputationKernel(
            data=thedata_sub, # data con valores perdidos
            datasets=4,# en cuantas copias imputar
            save_all_iterations=True,
            random_state=1 # seed
)

# Usar el kernel, 5 iteraciones en cada dataset
kernel.mice(5)

# %%
print(kernel)
# Out:
#               Class: ImputationKernel
#            Datasets: 4
#          Iterations: 5
#   Imputed Variables: 2
# save_all_iterations: True

# %%
thedata_sub_mice_mf = kernel.complete_data(dataset=0, inplace=False)
thedata_sub_mice_mf.columns=thedata_sub_mice_mf.columns+'_mf'
thedata_sub_mice_mf.describe()
# Out:
#        cobertura.cell_mf  Educ.sec.comp_mf  esp.vid.nacer_mf  \
# count        1874.000000       1874.000000       1874.000000
# mean           45.659178         55.769523         73.680183
# std            30.292175         15.728123          5.229458
# min             0.570613         11.974433         50.557694
# 25%            18.960182         44.466678         70.729725
# 50%            42.280607         57.164771         74.038561
# 75%            70.370370         68.202230         77.432747
# max           100.000000         91.744878         85.000000
#
#        Ing.fam.p.cap_mf  NBS.2017_mf  No.Pobreza_mf  Tasa.docen_pub_mf
# count       1874.000000  1874.000000    1874.000000        1874.000000
# mean         588.785567    61.406670      65.857929         210.146912
# std          365.103757    18.297153      16.904808          97.843127
# min           51.073334     0.600000      18.738329          14.306152
# 25%          306.545767    50.725000      53.234158         146.712682
# 50%          499.073047    64.700000      65.700570         203.430403
# 75%          804.306417    75.100000      79.092820         260.246819
# max         2037.326546    98.900000      99.942654        1123.595506

# %%
kernel.plot_feature_importance(dataset=0, annot=True,cmap="YlGnBu",vmin=0, vmax=1)
# Out:
# AxesSubplot(0.125,0.125;0.62x0.755)

# %%
import sys
import sklearn.neighbors._base
sys.modules['sklearn.neighbors.base'] = sklearn.neighbors._base
####
from fancyimpute import KNN
from fancyimpute import IterativeImputer
from missingpy import MissForest



knn_imputer = KNN()
mice_imputer = IterativeImputer()
imputerFOR = MissForest(criterion='squared_error')

thedata_sub_mice = mice_imputer.fit_transform(thedata_sub)
thedata_sub_knn = knn_imputer.fit_transform(thedata_sub)
thedata_sub_for = imputerFOR.fit_transform(thedata_sub)

thedata_sub_mice=pd.DataFrame(thedata_sub_mice, columns=theVars+'_mice')
thedata_sub_knn=pd.DataFrame(thedata_sub_knn, columns=theVars+'_knn')
thedata_sub_for=pd.DataFrame(thedata_sub_for, columns=theVars+'_for')
# Out:
# Imputing row 1/1874 with 0 missing, elapsed time: 0.466
# Imputing row 101/1874 with 0 missing, elapsed time: 0.466
# Imputing row 201/1874 with 0 missing, elapsed time: 0.467
# Imputing row 301/1874 with 0 missing, elapsed time: 0.467
# Imputing row 401/1874 with 0 missing, elapsed time: 0.467
# Imputing row 501/1874 with 0 missing, elapsed time: 0.468
# Imputing row 601/1874 with 0 missing, elapsed time: 0.468
# Imputing row 701/1874 with 0 missing, elapsed time: 0.469
# Imputing row 801/1874 with 0 missing, elapsed time: 0.469
# Imputing row 901/1874 with 0 missing, elapsed time: 0.469
# Imputing row 1001/1874 with 0 missing, elapsed time: 0.470
# Imputing row 1101/1874 with 0 missing, elapsed time: 0.470
# Imputing row 1201/1874 with 0 missing, elapsed time: 0.471
# Imputing row 1301/1874 with 0 missing, elapsed time: 0.471
# Imputing row 1401/1874 with 0 missing, elapsed time: 0.471
# Imputing row 1501/1874 with 0 missing, elapsed time: 0.472
# Imputing row 1601/1874 with 0 missing, elapsed time: 0.472
# Imputing row 1701/1874 with 0 missing, elapsed time: 0.472
# Imputing row 1801/1874 with 0 missing, elapsed time: 0.473
# Iteration: 0
# Iteration: 1
# Iteration: 2
# Iteration: 3

# %%
AllData=pd.concat([thedata_sub,thedata_sub_mice,thedata_sub_knn,thedata_sub_for,thedata_sub_mice_mf],axis=1)

# %%
select=AllData.columns[AllData.columns.str.contains("cober|docen")]
select=sorted(select)
select
# Out:
# ['Tasa.docen_pub',
#  'Tasa.docen_pub_for',
#  'Tasa.docen_pub_knn',
#  'Tasa.docen_pub_mf',
#  'Tasa.docen_pub_mice',
#  'cobertura.cell',
#  'cobertura.cell_for',
#  'cobertura.cell_knn',
#  'cobertura.cell_mf',
#  'cobertura.cell_mice']

# %%
AllData[select].describe()
# Out:
#        Tasa.docen_pub  Tasa.docen_pub_for  Tasa.docen_pub_knn  \
# count     1873.000000         1874.000000         1874.000000
# mean       210.196649          210.149305          210.135573
# std         97.845558           97.840902           97.855159
# min         14.306152           14.306152           14.306152
# 25%        147.040693          146.712682          146.712682
# 50%        203.470975          203.430403          203.430403
# 75%        260.290557          260.246819          260.246819
# max       1123.595506         1123.595506         1123.595506
#
#        Tasa.docen_pub_mf  Tasa.docen_pub_mice  cobertura.cell  \
# count        1874.000000          1874.000000     1852.000000
# mean          210.146912           210.146786       45.940745
# std            97.843127            97.843248       30.289883
# min            14.306152            14.306152        0.570613
# 25%           146.712682           146.712682       19.593254
# 50%           203.430403           203.430403       42.802617
# 75%           260.246819           260.246819       70.649510
# max          1123.595506          1123.595506      100.000000
#
#        cobertura.cell_for  cobertura.cell_knn  cobertura.cell_mf  \
# count         1874.000000         1874.000000        1874.000000
# mean            45.712322           45.704869          45.659178
# std             30.219238           30.208732          30.292175
# min              0.570613            0.570613           0.570613
# 25%             19.249356           19.494048          18.960182
# 50%             42.201141           42.105263          42.280607
# 75%             70.370370           70.370370          70.370370
# max            100.000000          100.000000         100.000000
#
#        cobertura.cell_mice
# count          1874.000000
# mean             45.703117
# std              30.237367
# min              -6.524194
# 25%              19.360627
# 50%              42.201141
# 75%              70.370370
# max             100.000000

# %%
AllData_imp=AllData.loc[:,select]
AllData_imp
# Out:
#       Tasa.docen_pub  Tasa.docen_pub_for  Tasa.docen_pub_knn  \
# 0         200.541634          200.541634          200.541634
# 1         138.888889          138.888889          138.888889
# 2         188.564477          188.564477          188.564477
# 3         287.648054          287.648054          287.648054
# 4         101.892285          101.892285          101.892285
# ...              ...                 ...                 ...
# 1869      206.832872          206.832872          206.832872
# 1870      251.228227          251.228227          251.228227
# 1871      265.245708          265.245708          265.245708
# 1872      136.268344          136.268344          136.268344
# 1873      354.305347          354.305347          354.305347
#
#       Tasa.docen_pub_mf  Tasa.docen_pub_mice  cobertura.cell  \
# 0            200.541634           200.541634       87.500000
# 1            138.888889           138.888889       11.111111
# 2            188.564477           188.564477       32.142857
# 3            287.648054           287.648054        6.250000
# 4            101.892285           101.892285       30.232558
# ...                 ...                  ...             ...
# 1869         206.832872           206.832872       18.840580
# 1870         251.228227           251.228227       10.000000
# 1871         265.245708           265.245708       20.689655
# 1872         136.268344           136.268344       78.571429
# 1873         354.305347           354.305347        1.818182
#
#       cobertura.cell_for  cobertura.cell_knn  cobertura.cell_mf  \
# 0              87.500000           87.500000          87.500000
# 1              11.111111           11.111111          11.111111
# 2              32.142857           32.142857          32.142857
# 3               6.250000            6.250000           6.250000
# 4              30.232558           30.232558          30.232558
# ...                  ...                 ...                ...
# 1869           18.840580           18.840580          18.840580
# 1870           10.000000           10.000000          10.000000
# 1871           20.689655           20.689655          20.689655
# 1872           78.571429           78.571429          78.571429
# 1873            1.818182            1.818182           1.818182
#
#       cobertura.cell_mice
# 0               87.500000
# 1               11.111111
# 2               32.142857
# 3                6.250000
# 4               30.232558
# ...                   ...
# 1869            18.840580
# 1870            10.000000
# 1871            20.689655
# 1872            78.571429
# 1873             1.818182
#
# [1874 rows x 10 columns]

# %%
AllData_imp.loc[AllData_imp.isnull().any(axis=1),].reset_index(drop=True)
# Out:
#     Tasa.docen_pub  Tasa.docen_pub_for  Tasa.docen_pub_knn  Tasa.docen_pub_mf  \
# 0       110.192837          110.192837          110.192837         110.192837
# 1       283.790284          283.790284          283.790284         283.790284
# 2        95.011876           95.011876           95.011876          95.011876
# 3       276.422764          276.422764          276.422764         276.422764
# 4        50.000000           50.000000           50.000000          50.000000
# 5       186.958504          186.958504          186.958504         186.958504
# 6       410.094637          410.094637          410.094637         410.094637
# 7       323.799244          323.799244          323.799244         323.799244
# 8       273.269524          273.269524          273.269524         273.269524
# 9       143.833154          143.833154          143.833154         143.833154
# 10      308.087291          308.087291          308.087291         308.087291
# 11      260.290557          260.290557          260.290557         260.290557
# 12      234.948605          234.948605          234.948605         234.948605
# 13      246.376812          246.376812          246.376812         246.376812
# 14             NaN          121.474887           95.741321         116.989568
# 15      292.096220          292.096220          292.096220         292.096220
# 16      208.835341          208.835341          208.835341         208.835341
# 17      332.214377          332.214377          332.214377         332.214377
# 18      322.147651          322.147651          322.147651         322.147651
# 19      487.220447          487.220447          487.220447         487.220447
# 20      346.534653          346.534653          346.534653         346.534653
# 21      356.052899          356.052899          356.052899         356.052899
# 22      261.413844          261.413844          261.413844         261.413844
#
#     Tasa.docen_pub_mice  cobertura.cell  cobertura.cell_for  \
# 0            110.192837             NaN           25.729944
# 1            283.790284             NaN           14.010088
# 2             95.011876             NaN           60.674355
# 3            276.422764             NaN           42.338774
# 4             50.000000             NaN           30.262632
# 5            186.958504             NaN           29.584947
# 6            410.094637             NaN           19.597722
# 7            323.799244             NaN           35.124257
# 8            273.269524             NaN           36.310996
# 9            143.833154             NaN           31.378268
# 10           308.087291             NaN           17.530711
# 11           260.290557             NaN           55.344560
# 12           234.948605             NaN           22.281501
# 13           246.376812             NaN           37.112867
# 14           116.753132           100.0          100.000000
# 15           292.096220             NaN           11.233701
# 16           208.835341             NaN           23.539431
# 17           332.214377             NaN           19.214195
# 18           322.147651             NaN           12.763682
# 19           487.220447             NaN           17.998465
# 20           346.534653             NaN           12.246059
# 21           356.052899             NaN           14.331612
# 22           261.413844             NaN           14.023367
#
#     cobertura.cell_knn  cobertura.cell_mf  cobertura.cell_mice
# 0            35.018296          40.157480            21.490259
# 1            24.584515          19.718310            14.908923
# 2            30.473675          48.648649            52.512707
# 3            37.809544          37.500000            33.400419
# 4            45.344336           8.928571            49.055947
# 5            37.591677          40.000000            41.465580
# 6            22.545562          25.748503            30.887149
# 7            20.269069           2.816901            35.934287
# 8            27.888297          46.666667            37.188020
# 9            32.691031          14.285714            44.179362
# 10           30.929067           3.703704            14.692104
# 11           28.436022          42.105263            40.386020
# 12           23.420450          60.000000            22.847508
# 13           29.498593          47.619048            38.835387
# 14          100.000000         100.000000           100.000000
# 15           15.187372           2.941176             2.921343
# 16           33.068121          10.000000            23.060486
# 17           12.486330           2.586207            -6.524194
# 18           13.299908          11.111111            19.933103
# 19            6.357992          11.111111            19.005617
# 20           34.876475           1.481481            11.725710
# 21            9.708690           2.500000            15.093219
# 22           17.178841           3.409091             2.383049

# %%
AllData_imp.hist(layout=[2,5],figsize=(12,8))
# Out:
# array([[<AxesSubplot:title={'center':'Tasa.docen_pub'}>,
#         <AxesSubplot:title={'center':'Tasa.docen_pub_for'}>,
#         <AxesSubplot:title={'center':'Tasa.docen_pub_knn'}>,
#         <AxesSubplot:title={'center':'Tasa.docen_pub_mf'}>,
#         <AxesSubplot:title={'center':'Tasa.docen_pub_mice'}>],
#        [<AxesSubplot:title={'center':'cobertura.cell'}>,
#         <AxesSubplot:title={'center':'cobertura.cell_for'}>,
#         <AxesSubplot:title={'center':'cobertura.cell_knn'}>,
#         <AxesSubplot:title={'center':'cobertura.cell_mf'}>,
#         <AxesSubplot:title={'center':'cobertura.cell_mice'}>]],
#       dtype=object)

# %%
AllData_imp.plot(kind='box',rot=45,vert=False)
# Out:
# <AxesSubplot:>
